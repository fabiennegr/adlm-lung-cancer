# %%
import numpy as np
data_node1 = np.load('../images/predictions/wrong_23_nod1_7.npy')
data_node1 = data_node1.squeeze(0)
data_node1.shape
# Out:
# (41, 41, 16)

# %%
from matplotlib import pyplot as plt

plt.title('Slice 8 of wrong_23_nod1_7.npy')
plt.imshow(data_node1[:,:,8], cmap='gray')
plt.show()

# %%
data_node2 = np.load('../images/predictions/wrong_23_nod2_7.npy')
data_node2 = data_node2.squeeze(0)
data_node2.shape
# Out:
# (41, 41, 16)

# %%
plt.title('Slice 8 of wrong_23_nod2_7.npy')
plt.imshow(data_node2[:,:,8], cmap='gray')
plt.show()

# %%
data_node3 = np.load('../images/predictions/wrong_23_nod3_7.npy')
data_node3 = data_node3.squeeze(0)
data_node3.shape
# Out:
# (41, 41, 16)

# %%
plt.title('Slice 8 of wrong_23_nod3_7.npy')
plt.imshow(data_node3[20,:,:], cmap='gray')
plt.show()

# %%
# wrong predictions
data_node1_wrong = np.load('../images/predictions/wrong_18_nod1_6.npy')
data_node1_wrong = data_node1_wrong.squeeze(0)
data_node1_wrong.shape

data_node2_wrong = np.load('../images/predictions/wrong_18_nod2_6.npy')
data_node2_wrong = data_node2_wrong.squeeze(0)

data_node3_wrong = np.load('../images/predictions/wrong_18_nod3_6.npy')
data_node3_wrong = data_node3_wrong.squeeze(0)

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
ax[0].imshow(data_node1_wrong[:,:,8], cmap='gray')
ax[0].set_title('Nodule 1 - wrong_18_nod1_6')
ax[1].imshow(data_node2_wrong[:,:,8], cmap='gray')
ax[1].set_title('Nodule 2 - wrong_18_nod2_6')
ax[2].imshow(data_node3_wrong[:,:,8], cmap='gray')
ax[2].set_title('Nodule 3 - wrong_18_nod3_6')
plt.show()

# %%
# correct predictions
data_node1_correct = np.load('../images/predictions/correct_44_nod1_1.npy')
data_node1_correct = data_node1_correct.squeeze(0)

data_node2_correct = np.load('../images/predictions/correct_44_nod2_1.npy')
data_node2_correct = data_node2_correct.squeeze(0)

data_node3_correct = np.load('../images/predictions/correct_44_nod3_1.npy')
data_node3_correct = data_node3_correct.squeeze(0)

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
ax[0].imshow(data_node1_correct[:,:,8], cmap='gray')
ax[0].set_title('Nodule 1 - correct_44_nod1_1')
ax[1].imshow(data_node2_correct[:,:,8], cmap='gray')
ax[1].set_title('Nodule 2 - correct_44_nod2_1')
ax[2].imshow(data_node3_correct[:,:,8], cmap='gray')
ax[2].set_title('Nodule 3 - correct_44_nod3_1')
plt.show()
